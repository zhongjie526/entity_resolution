# %%
import pandas as pd

invoice = pd.read_excel("CCN 4189 FBL5N_Jul-Dec 2017.XLSX")
invoice
# Out:
#        Account                  Account Name         Reference  \
# 0      8364077         Z ENERGY 2015 LIMITED       JPM 11AUG17
# 1      8364077         Z ENERGY 2015 LIMITED      JPM 22SEPT17
# 2      8364077         Z ENERGY 2015 LIMITED       JPM 31OCT17
# 3      8364077         Z ENERGY 2015 LIMITED       JPM 01NOV17
# 4      8364077         Z ENERGY 2015 LIMITED      JPM 29SEPT17
# 5      8364077         Z ENERGY 2015 LIMITED     JPM 29DEC2017
# 6      8364077         Z ENERGY 2015 LIMITED      JPM 05SEPT17
# 7      8364077         Z ENERGY 2015 LIMITED     JPM 14DEC2017
# 8      8364077         Z ENERGY 2015 LIMITED       JPM 21JUL17
# 9      8364077         Z ENERGY 2015 LIMITED            127025
# 10     8364077         Z ENERGY 2015 LIMITED            127099
# 11     8364077         Z ENERGY 2015 LIMITED            127106
# 12     8364077         Z ENERGY 2015 LIMITED            127149
# 13     8364077         Z ENERGY 2015 LIMITED            127149
# ...

# %%
bank = pd.read_excel("CCN 4189 Bank Statements_JPM_Oct-Dec 2017.xls",sheet_name="Details")
bank
# Out:
#        Bank ID                          Bank Name Currency  Account Number  \
# 0     02100002            JPMORGAN CHASE NEW YORK      USD       400944758
# 1     02100002            JPMORGAN CHASE NEW YORK      USD       400944758
# 2     02100002            JPMORGAN CHASE NEW YORK      USD       400944758
# 3     02100002            JPMORGAN CHASE NEW YORK      USD       400944758
# 4     02100002            JPMORGAN CHASE NEW YORK      USD       400944758
# 5     CHASSGSG  JPMorgan Chase Bank, NA Singapore      SGD       111870401
# 6     CHASSGSG  JPMorgan Chase Bank, NA Singapore      SGD       111870401
# 7     CHASSGSG  JPMorgan Chase Bank, NA Singapore      SGD       111870401
# 8     CHASSGSG  JPMorgan Chase Bank, NA Singapore      SGD       111870401
# 9     CHASSGSG  JPMorgan Chase Bank, NA Singapore      SGD       111870401
# 10    CHASSGSG  JPMorgan Chase Bank, NA Singapore      SGD       111870401
# ...

# %%
invoice[invoice.Reference=='17529793']
# Out:
#        Account                  Account Name Reference  Document Number  \
# 77544  8217255  BILSEA INTERNATIONAL PTE LTD  17529793         78003364
#
#                                             Text  User name  Company Code  \
# 77544  Rostella-20170930-Asphalt BTB  2017-09Sep  XI_PC8008          4189
#
#       Posting Date Document Date Baseline Payment Dte Net due date  \
# 77544   2017-09-01    2017-09-30           2017-10-11   2017-10-11
#
#       Document currency  Amount in doc. curr. Local Currency  \
# 77544               USD              65599.88            USD
#
#        Amount in local currency Local currency 2  Amount in loc.curr.2  \
# 77544                  65599.88              USD              65599.88
#
#       Clearing date  Clearing Document
# 77544    2017-10-13         14001795.0

# %%
print "There are {0} transactions in the bank statements".format(len(bank['Customer Reference'].values))
# Out:
# There are 1322 transactions in the bank statements

# %%
'17529793' in set(bank['Customer Reference'].values)
# Out:
# False

# %%
for cust_ref in set(bank['Customer Reference'].values):
    if '17529793' in str(cust_ref):
        print cust_ref
# Out:
# 17529793/BS0009
