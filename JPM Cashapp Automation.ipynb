# %%
import pandas as pd
import math
import re
import distance
import nltk
from datetime import datetime
import numpy as np

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
def tokenize(sent):
    """
    When passed in a sentence, tokenizes and normalizes the string,
    returning a list of lemmata.
    """
    lemmatizer = nltk.WordNetLemmatizer() 
    for token in nltk.wordpunct_tokenize(sent):
        token = token.lower()
        yield lemmatizer.lemmatize(token)

def normalized_jaccard(*args):
    try:
        return distance.jaccard(*[tokenize(arg) for arg in args])
    except UnicodeDecodeError:
        return 1.0
    
def wordsim(*args):
    return 1.0-normalized_jaccard(*args)

# %%
invoice = pd.read_excel("CCN 4189 FBL5N_Jul-Dec 2017.XLSX",\
                        dtype={'Reference':'str',\
                               'Document Number':'str',\
                               'Clearing Document':'str'})

invoice_1 = invoice[(invoice['Clearing date'] < '20171231') \
                    & (invoice['Posting Date'] > '20170701') \
                    & (invoice['Amount in doc. curr.'] > 0)]

invoice_1.head()
# Out:
#     Account           Account Name Reference Document Number Text User name  \
# 9   8364077  Z ENERGY 2015 LIMITED    127025       974947086  NaN      TCLT
# 10  8364077  Z ENERGY 2015 LIMITED    127099       974952978  NaN      TCLT
# 11  8364077  Z ENERGY 2015 LIMITED    127106       974954292  NaN      TCLT
# 12  8364077  Z ENERGY 2015 LIMITED    127149       974963972  NaN      TCLT
# 13  8364077  Z ENERGY 2015 LIMITED    127149       974968703  NaN      TCLT
#
#     Company Code Posting Date Document Date Baseline Payment Dte Net due date  \
# 9           4189   2017-07-04    2017-07-04           2017-07-04   2017-09-02
# 10          4189   2017-07-25    2017-07-25           2017-07-25   2017-09-23
# 11          4189   2017-07-31    2017-07-31           2017-07-31   2017-09-29
# 12          4189   2017-09-05    2017-09-05           2017-09-05   2017-11-04
# 13          4189   2017-09-05    2017-09-21           2017-09-05   2017-11-04
#
#    Document currency  Amount in doc. curr. Local Currency  \
# 9                USD              82557.86            USD
# 10               USD              24960.00            USD
# 11               USD              53486.00            USD
# 12               USD              50240.00            USD
# 13               USD                320.00            USD
#
#     Amount in local currency Local currency 2  Amount in loc.curr.2  \
# 9                   82557.86              USD              82557.86
# 10                  24960.00              USD              24960.00
# 11                  53486.00              USD              53486.00
# 12                  50240.00              USD              50240.00
# 13                    320.00              USD                320.00
#
#    Clearing date Clearing Document
# 9     2017-09-05          14002573
# 10    2017-09-22          14000721
# 11    2017-09-29          14001766
# 12    2017-10-31          14000834
# 13    2017-12-14          14002857

# %%
def write_to_excel(df,name):
    writer = pd.ExcelWriter(name,  datetime_format='MM/dd/yyyy')
    df.to_excel(writer,index=False)
    writer.close()

# %%
invoice_uncleared = invoice_1[invoice_1['Document Number']!=invoice_1['Clearing Document']]
print "There are {0} transactions in the invoice".format(len(invoice_1))
print "There are {0} transactions in the uncleared invoice".format(len(invoice_uncleared))

write_to_excel(invoice_uncleared,"CCN 4189 uncleared.xls")
# Out:
# There are 47102 transactions in the invoice
# There are 46630 transactions in the uncleared invoice

# %%
set_document_uncleared = set(invoice_uncleared['Document Number'].values)

len(set_document_uncleared)
# Out:
# 45920

# %%
bank = pd.read_excel("CCN 4189 Bank Statements_JPM_Oct-Dec 2017.xls",sheet_name="Details",\
                     dtype={'Remarks 1':'str','Remarks 2':'str','Remarks 3':'str','Remarks 4':'str',\
                            'Remarks 5':'str','Remarks 6':'str'})
bank.head()
# Out:
#     Bank ID                Bank Name Currency  Account Number  \
# 0  02100002  JPMORGAN CHASE NEW YORK      USD       400944758
# 1  02100002  JPMORGAN CHASE NEW YORK      USD       400944758
# 2  02100002  JPMORGAN CHASE NEW YORK      USD       400944758
# 3  02100002  JPMORGAN CHASE NEW YORK      USD       400944758
# 4  02100002  JPMORGAN CHASE NEW YORK      USD       400944758
#
#                        Account Name Transaction Date Value Date  \
# 0  CHEVRON SINGAPORE PTE LTD - FAMM       2017-10-02 2017-10-02
# 1  CHEVRON SINGAPORE PTE LTD - FAMM       2017-10-02 2017-10-02
# 2  CHEVRON SINGAPORE PTE LTD - FAMM       2017-10-02 2017-10-02
# 3  CHEVRON SINGAPORE PTE LTD - FAMM       2017-10-02 2017-10-02
# 4  CHEVRON SINGAPORE PTE LTD - FAMM              NaT        NaT
#
#             Description Customer Reference Bank Reference       ...         \
# 0  BOOK TRANSFER CREDIT    SWF OF 17/10/02   1412600275HA       ...
# 1          CHIPS CREDIT   O/B DBTCO AMERIC   4000500275FC       ...
# 2          CHIPS CREDIT    1IR710024595C01   2272800275FC       ...
# 3          CHIPS CREDIT   ST10501710020844   3492800275FC       ...
# 4         Debit Summary            2 items            NaN       ...
#
#               Remarks 7            Remarks 8  Remarks 9  Remarks 10  \
# 0                   NaN                  NaN        NaN         NaN
# 1  CHIP SEQ    =0017062  CHIP REF    =201088        NaN         NaN
# 2  CHIP SEQ    =0009109  CHIP REF    =113192        NaN         NaN
# 3  CHIP SEQ    =0010906  CHIP REF    =176057        NaN         NaN
# 4                   NaN                  NaN        NaN         NaN
#
#    Remarks 11  Remarks 12  Remarks 13 Remarks 14 Remarks 15 Transaction Time
# 0         NaN         NaN         NaN        NaN        NaN         06:22 AM
# 1         NaN         NaN         NaN        NaN        NaN         06:22 AM
# 2         NaN         NaN         NaN        NaN        NaN         12:53 AM
# 3         NaN         NaN         NaN        NaN        NaN         05:23 AM
# 4         NaN         NaN         NaN        NaN        NaN              NaN
#
# [5 rows x 33 columns]

# %%
bank_1 = bank[(bank['Description'] != 'Debit Summary') & (bank['Description'] != 'Check Summary')]
print "There are {0} transactions in the bank statements".format(len(bank_1))
write_to_excel(bank_1,"CCN 4189 bank statements.xls")
# Out:
# There are 1079 transactions in the bank statements

# %%
def days_between(d1, d2):
    return abs(d2 - d1)/np.timedelta64(1, 'D')

# %%
n_customer=0
n_no_customer=0
n_match=0
lst_customer=[]
lst_name_match=[]
matches=[]

for index,row in bank_1[:200].iterrows():
    print "========================================================================="
    remarks = row['Remarks 1']+"|"+row['Remarks 2']+"|"+row['Remarks 3']+"|"+row['Remarks 4']+"|"+\
              row['Remarks 5']+"|"+row['Remarks 6']
    remarks = re.sub( '[\s\.]+', ' ',remarks).strip()
    remarks = remarks.replace('PETRON1/AS','PETRONAS')
    remarks = remarks.replace('PTE LT1','PTE LTD 1')
    remarks = remarks.replace('PTE LTDPAY','PTE LTD PAY')
    remarks = remarks.replace('PRIVATE LTD','PTE LTD')
    remarks = remarks.replace('LTD','LTD|')
    remarks = remarks.replace('PLC','PLC|')
    match_result = re.match(r".*B\/O CUSTOMER[\W\d\d]*([a-zA-Z\s\(\)\&]+).*",remarks)
    if match_result==None:
        print "no customer name: "+ remarks 
        n_no_customer+=1

    else:
        cust_name = match_result.group(1).replace("PTE","").replace("LTD","").replace("PLC","").strip()
        print"customer name found: "+cust_name
        n_customer+=1
        lst_customer.append(cust_name)
        amt = row['Credit Amount']
        date = row['Transaction Date']
        print "Transaction date: {1:'%Y-%m-%d'}, Credit amount: {0}, Customer Name: {2}".format(amt,date,cust_name)
        
        date_matched = invoice_1[(invoice_1['Net due date']>=date) & (invoice_1['Posting Date']<=date)]
        n_date_matched= len(date_matched)
        print "{0} invoices matches".format(n_date_matched)
        
        if(n_date_matched>0):
            match = date_matched.to_dict('records')
     
            for each in match:
                acc_inv = each['Account Name'].replace("PTE","").replace("LTD","").replace("PLC","").strip()
                amt_inv = each['Amount in doc. curr.']
                date_inv = each['Net due date']
                doc_inv = each['Document Number']
                name_score = wordsim(acc_inv,cust_name)
                amt_score = 1.0-abs(amt_inv/amt-1.0)
                date_score =  1.0-days_between(date,date_inv)/10.0
                final_score = name_score*0.18+amt_score*0.18+date_score*0.64
                

                if(final_score>0.9):
                    #print "name score: {0}  amount score: {1}  date score: {2} final score: {3}".\
                     #   format(name_score,amt_score,date_score,final_score)
                    print "invoice {3}: amount {0} from account {2} due on {1:'%Y-%m-%d'} final score: {4}".\
                        format(amt_inv,date_inv,acc_inv,doc_inv,final_score)
                    n_match+=1
                    matches.append({"Bank acc":cust_name,\
                                    "Bank date":date,"Bank amt":amt,\
                                    "Invoice acc":acc_inv,"Invoice amt":amt_inv,\
                                    "Invoice due":date_inv, "Name score":name_score,\
                                    "Amount score":amt_score,"Date score":date_score,\
                                    "Final score":final_score
                                    })
            
        else:
            print "no date range"

            #print date_matched[['Account Name','Net due date','Amount in doc. curr.']]
        

print "customer names found: {0}".format(n_customer)
print "customer names not found: {0}".format(n_no_customer)
print "final match count: {0}".format(n_match)
# Out:
# =========================================================================
# customer name found: HIN HIN TRADING
# Transaction date: '2017-10-02', Credit amount: 1072538.46, Customer Name: HIN HIN TRADING
# 6151 invoices matches
# invoice 78000256: amount 1072563.46 from account HIN HIN TRADING due on '2017-10-02' final score: 0.999995804346
# =========================================================================
# customer name found: GLENCORE SINGAPORE
# Transaction date: '2017-10-02', Credit amount: 927560.58, Customer Name: GLENCORE SINGAPORE
# 6151 invoices matches
# invoice 78010644: amount 476495.5 from account GLENCORE SINGAPORE due on '2017-10-02' final score: 0.912467480668
# invoice 78010646: amount 450635.08 from account GLENCORE SINGAPORE due on '2017-10-02' final score: 0.907449074647
# =========================================================================
# customer name found: MERCURIA ENERGY TRADING
# Transaction date: '2017-10-02', Credit amount: 629371.84, Customer Name: MERCURIA ENERGY TRADING
# 6151 invoices matches
# invoice 78000282: amount 629371.84 from account MERCURIA ENERGY TRADING due on '2017-10-02' final score: 1.0
# =========================================================================
# customer name found: SINOPEC FUEL OIL (SINGAPORE)
# Transaction date: '2017-10-02', Credit amount: 4272.0, Customer Name: SINOPEC FUEL OIL (SINGAPORE)
# 6151 invoices matches
# invoice 14002648: amount 4300.0 from account SINOPEC FUEL OIL (SINGAPORE) due on '2017-10-02' final score: 0.998820224719
# =========================================================================
# no customer name: YOUR REF =JPM021017000004|MAT DATE =03OCT17|PAY METHOD =CHECK DEPOSIT|PAYDET =D5006782|nan|nan
# =========================================================================
# customer name found: MING HUP TRADING
# Transaction date: '2017-10-02', Credit amount: 403559.69, Customer Name: MING HUP TRADING
# 6151 invoices matches
# =========================================================================
# customer name found: ASIAPAC TRADING
# Transaction date: '2017-10-02', Credit amount: 111095.53, Customer Name: ASIAPAC TRADING
# 6151 invoices matches
# =========================================================================
# customer name found: OPEC
# Transaction date: '2017-10-02', Credit amount: 105020.5, Customer Name: OPEC
# 6151 invoices matches
# =========================================================================
# customer name found: AMAZE CARCARE SERVICES
# Transaction date: '2017-10-02', Credit amount: 25166.4, Customer Name: AMAZE CARCARE SERVICES
# 6151 invoices matches
# =========================================================================
# customer name found: JURONG BARRELS & DRUMS IND
# Transaction date: '2017-10-02', Credit amount: 6751.7, Customer Name: JURONG BARRELS & DRUMS IND
# 6151 invoices matches
# =========================================================================
# customer name found: SG SHIPPING
# Transaction date: '2017-10-02', Credit amount: 3072.0, Customer Name: SG SHIPPING
# 6151 invoices matches
# =========================================================================
# customer name found: ANZ SG
# Transaction date: '2017-10-02', Credit amount: 2939.1, Customer Name: ANZ SG
# 6151 invoices matches
# =========================================================================
# customer name found: SPORE POST
# Transaction date: '2017-10-02', Credit amount: 2140.0, Customer Name: SPORE POST
# 6151 invoices matches
# =========================================================================
# no customer name: PAYDET =SWEEP REFTo: 0151854124 USD SingaporeFr: 0151874494 USD SingaporeIntercompany LPQ883727506260|nan|nan|nan|nan|nan
# =========================================================================
# customer name found: CHEVRON SINGAPORE
# Transaction date: '2017-10-02', Credit amount: 10207.8, Customer Name: CHEVRON SINGAPORE
# 6151 invoices matches
# =========================================================================
# no customer name: REMARK =CASH CONCENTRATION TRANSFER CREDIT FROM ACCOUNT 000000400908654 TRN: 0001860730XF|nan|nan|nan|nan|nan
# =========================================================================
# customer name found: EXXONMOBIL OIL CORPORATION
# Transaction date: '2017-10-03', Credit amount: 1641265.72, Customer Name: EXXONMOBIL OIL CORPORATION
# 6311 invoices matches
# =========================================================================
# customer name found: COASTAL OIL SINGAPORE
# Transaction date: '2017-10-03', Credit amount: 1622409.22, Customer Name: COASTAL OIL SINGAPORE
# 6311 invoices matches
# =========================================================================
# customer name found: KAIROS OIL TRADING
# Transaction date: '2017-10-03', Credit amount: 1185873.27, Customer Name: KAIROS OIL TRADING
# 6311 invoices matches
# invoice 78000274: amount 1185918.27 from account KAIROS OIL TRADING due on '2017-10-03' final score: 0.999993169591
# =========================================================================
# customer name found: GLENCORE SINGAPORE
# Transaction date: '2017-10-03', Credit amount: 659446.36, Customer Name: GLENCORE SINGAPORE
# 6311 invoices matches
# invoice 78010643: amount 452543.04 from account GLENCORE SINGAPORE due on '2017-10-03' final score: 0.943524447386
# =========================================================================
# no customer name: YOUR REF =17526812/PM0008|REC FROM =00000000010975001 JP MORGAN CHASE BANK SINGAPORE 17/F, CAPITAL TOWER 168 ROBINSON ROAD SINGAPORE SINGAPORE 06891-2|REMARK =/BNF/BEING PAYMENT UNDER YOUR REF NO 17526812/PM0008 DEBIT REF ASGSGF010618|REC GFP =10030957|nan|nan
# =========================================================================
# customer name found: AXIS FOCUS SDN BHD SUITE
# Transaction date: '2017-10-03', Credit amount: 47149.81, Customer Name: AXIS FOCUS SDN BHD SUITE
# 6311 invoices matches
# =========================================================================
# customer name found: SAMBO E&C CO
# Transaction date: '2017-10-03', Credit amount: 608650.62, Customer Name: SAMBO E&C CO
# 6311 invoices matches
# =========================================================================
# no customer name: YOUR REF =JPM031017000003|MAT DATE =04OCT17|PAY METHOD =CHECK DEPOSIT|PAYDET =D5007468|nan|nan
# =========================================================================
# customer name found: AMERICAN EXPRESS INTERNATIONAL INC
# Transaction date: '2017-10-03', Credit amount: 168300.0, Customer Name: AMERICAN EXPRESS INTERNATIONAL INC
# 6311 invoices matches
# =========================================================================
# customer name found: NETS (S) Pte Ltd
# Transaction date: '2017-10-03', Credit amount: 2140.0, Customer Name: NETS (S) Pte Ltd
# 6311 invoices matches
# =========================================================================
# no customer name: EXCH RATE =1 0000000|PAY METHOD =BOOK TRANSFER|BENEFICIARY =CHEVRON SINGAPORE PTE LTD||REC FROM =JPMORGAN CHASE BANK, N A ,|BENE ACCOUNT=151854124|PAYDET =/TELEBEN//INS/CITIUS33///CHPREF/0145741
# =========================================================================
# customer name found: GLENCORE SINGAPORE
# Transaction date: '2017-10-04', Credit amount: 1761583.55, Customer Name: GLENCORE SINGAPORE
# 7846 invoices matches
# invoice 78002265: amount 1761153.55 from account GLENCORE SINGAPORE due on '2017-10-04' final score: 0.99995606226
# =========================================================================
# customer name found: H HIN HIN TRADING
# Transaction date: '2017-10-04', Credit amount: 1167580.0, Customer Name: H HIN HIN TRADING
# 7846 invoices matches
# =========================================================================
# customer name found: MPT OIL
# Transaction date: '2017-10-04', Credit amount: 200000.0, Customer Name: MPT OIL
# 7846 invoices matches
# =========================================================================
# no customer name: YOUR REF =JPM041017000006|MAT DATE =05OCT17|PAY METHOD =CHECK DEPOSIT|PAYDET =D5009267|nan|nan
# =========================================================================
# customer name found: OCBC GROUP ACCOUNTS
# Transaction date: '2017-10-04', Credit amount: 82050.3, Customer Name: OCBC GROUP ACCOUNTS
# 7846 invoices matches
# =========================================================================
# customer name found: SHELL EASTERN PETROLEUM () LIMIT
# Transaction date: '2017-10-04', Credit amount: 10753546.97, Customer Name: SHELL EASTERN PETROLEUM () LIMIT
# 7846 invoices matches
# =========================================================================
# customer name found: CHEVRON HONG KONG
# Transaction date: '2017-10-04', Credit amount: 135651.4, Customer Name: CHEVRON HONG KONG
# 7846 invoices matches
# =========================================================================
# customer name found: FUCHS LUBRICANTS INDIA PVT
# Transaction date: '2017-10-04', Credit amount: 18011.18, Customer Name: FUCHS LUBRICANTS INDIA PVT
# 7846 invoices matches
# =========================================================================
# no customer name: VAL DATE =01OCT17|PAYDET =INTEREST DUE TO ITMS BACK VALUED TO PRIOR INTEREST PERIOD 20170901 TO 20170930|nan|nan|nan|nan
# =========================================================================
# customer name found: EXXONMOBIL OIL CORPORATION
# Transaction date: '2017-10-05', Credit amount: 1773548.67, Customer Name: EXXONMOBIL OIL CORPORATION
# 6689 invoices matches
# =========================================================================
# customer name found: CUST
# Transaction date: '2017-10-05', Credit amount: 1747310.05, Customer Name: CUST
# 6689 invoices matches
# =========================================================================
# customer name found: BILSEA INTERNATIONAL
# Transaction date: '2017-10-05', Credit amount: 1374761.95, Customer Name: BILSEA INTERNATIONAL
# 6689 invoices matches
# =========================================================================
# customer name found: KAIROS OIL TRADING
# Transaction date: '2017-10-05', Credit amount: 1068225.66, Customer Name: KAIROS OIL TRADING
# 6689 invoices matches
# invoice 78000273: amount 1043338.72 from account KAIROS OIL TRADING due on '2017-10-05' final score: 0.995806457973
# =========================================================================
# customer name found: GLENCORE SINGAPORE
# Transaction date: '2017-10-05', Credit amount: 1049199.95, Customer Name: GLENCORE SINGAPORE
# 6689 invoices matches
# invoice 78012422: amount 617034.1 from account GLENCORE SINGAPORE due on '2017-10-05' final score: 0.92585793299
# =========================================================================
# customer name found: PETROLIAM NASIONAL BERHAD (PETRONAS)
# Transaction date: '2017-10-05', Credit amount: 337259.9, Customer Name: PETROLIAM NASIONAL BERHAD (PETRONAS)
# 6689 invoices matches
# =========================================================================
# no customer name: PAYDET =SWEEP REFTo: 0111870401 SGD SingaporeFr: 0111874478 SGD SingaporeIntercompany LPQ883727805509|nan|nan|nan|nan|nan
# =========================================================================
# no customer name: YOUR REF =JPM051017000005|MAT DATE =06OCT17|PAY METHOD =CHECK DEPOSIT|PAYDET =D5009269|nan|nan
# =========================================================================
# customer name found: OPEC
# Transaction date: '2017-10-05', Credit amount: 101022.39, Customer Name: OPEC
# 6689 invoices matches
# =========================================================================
# customer name found: TEN & HAN TRADING
# Transaction date: '2017-10-05', Credit amount: 25169.05, Customer Name: TEN & HAN TRADING
# 6689 invoices matches
# =========================================================================
# customer name found: INCHCAPE SHIPPING SERVICES (S) P L
# Transaction date: '2017-10-05', Credit amount: 9000.0, Customer Name: INCHCAPE SHIPPING SERVICES (S) P L
# 6689 invoices matches
# =========================================================================
# no customer name: PAYDET =SWEEP REFTo: 0151854124 USD SingaporeFr: 0151874494 USD SingaporeIntercompany LPQ883727805463|nan|nan|nan|nan|nan
# =========================================================================
# customer name found: CHEVRON SINGAPORE
# Transaction date: '2017-10-05', Credit amount: 240000.0, Customer Name: CHEVRON SINGAPORE
# 6689 invoices matches
# =========================================================================
# customer name found: AMPOL SINGAPORE TRADING
# Transaction date: '2017-10-05', Credit amount: 187860.0, Customer Name: AMPOL SINGAPORE TRADING
# 6689 invoices matches
# =========================================================================
# no customer name: REMARK =CASH CONCENTRATION TRANSFER CREDIT FROM ACCOUNT 000000400908654 TRN: 0002060730XF|nan|nan|nan|nan|nan
# =========================================================================
# customer name found: KAIROS OIL TRADING
# Transaction date: '2017-10-06', Credit amount: 1762455.69, Customer Name: KAIROS OIL TRADING
# 6878 invoices matches
# invoice 78000279: amount 1747097.32 from account KAIROS OIL TRADING due on '2017-10-06' final score: 0.998431446183
# =========================================================================
# customer name found: EQUATORIAL MARINE FUEL MANAGEMENT SERVICES
# Transaction date: '2017-10-06', Credit amount: 903753.87, Customer Name: EQUATORIAL MARINE FUEL MANAGEMENT SERVICES
# 6878 invoices matches
# invoice 78010653: amount 903343.87 from account EQUATORIAL MARINE FUEL MANAGEMENT due on '2017-10-06' final score: 0.963918340599
# =========================================================================
# customer name found: COASTAL OIL SINGAPORE
# Transaction date: '2017-10-06', Credit amount: 699998.81, Customer Name: COASTAL OIL SINGAPORE
# 6878 invoices matches
# invoice 78012458: amount 699998.81 from account COASTAL OIL SPORE due on '2017-10-06' final score: 0.91
# =========================================================================
# no customer name: YOUR REF =17527781/PM0009|REC FROM =00000000010975001 JP MORGAN CHASE BANK SINGAPORE 17/F, CAPITAL TOWER 168 ROBINSON ROAD SINGAPORE SINGAPORE 06891-2|REMARK =/BNF/BEING PAYMENT UNDER YOUR REF NO 17527781/PM0009 DEBIT REF ASGSGF010806|REC GFP =10061142|nan|nan
# =========================================================================
# no customer name: YOUR REF =17527856/PM0009|REC FROM =00000000010975001 JP MORGAN CHASE BANK SINGAPORE 17/F, CAPITAL TOWER 168 ROBINSON ROAD SINGAPORE SINGAPORE 06891-2|REMARK =/BNF/BEING PAYMENT UNDER YOUR REF NO 17527856/PM0009 DEBIT REF ASGSGF010858|REC GFP =10061146|nan|nan
# =========================================================================
# customer name found: HIN HIN TRADING
# Transaction date: '2017-10-06', Credit amount: 36469.96, Customer Name: HIN HIN TRADING
# 6878 invoices matches
# =========================================================================
# customer name found: PETROLIAM NASIONAL BERHAD (PETRONAS)
# Transaction date: '2017-10-06', Credit amount: 25060.71, Customer Name: PETROLIAM NASIONAL BERHAD (PETRONAS)
# 6878 invoices matches
# =========================================================================
# customer name found: EXXONMOBIL OIL CORPORATION
# Transaction date: '2017-10-06', Credit amount: 8905.09, Customer Name: EXXONMOBIL OIL CORPORATION
# 6878 invoices matches
# =========================================================================
# customer name found: MERCURIA ENERGY TRADING
# Transaction date: '2017-10-06', Credit amount: 4484.09, Customer Name: MERCURIA ENERGY TRADING
# 6878 invoices matches
# invoice 78002262: amount 4484.09 from account MERCURIA ENERGY TRADING due on '2017-10-06' final score: 1.0
# =========================================================================
# no customer name: YOUR REF =JPM061017000002|MAT DATE =09OCT17|PAY METHOD =CHECK DEPOSIT|PAYDET =D5009270|nan|nan
# =========================================================================
# no customer name: PAYDET =SWEEP REFTo: 0111870401 SGD SingaporeFr: 0111874478 SGD SingaporeIntercompany LPQ883727905517|nan|nan|nan|nan|nan
# =========================================================================
# customer name found: MPA
# Transaction date: '2017-10-06', Credit amount: 17039.2, Customer Name: MPA
# 6878 invoices matches
# =========================================================================
# customer name found: SG SHIPPING
# Transaction date: '2017-10-06', Credit amount: 3477.36, Customer Name: SG SHIPPING
# 6878 invoices matches
# =========================================================================
# customer name found: CHEVRON SINGAPORE
# Transaction date: '2017-10-06', Credit amount: 26.4, Customer Name: CHEVRON SINGAPORE
# 6878 invoices matches
# =========================================================================
# customer name found: AMPOL SINGAPORE TRADING
# Transaction date: '2017-10-06', Credit amount: 2674315.08, Customer Name: AMPOL SINGAPORE TRADING
# 6878 invoices matches
# =========================================================================
# no customer name: PAYDET =SWEEP REFTo: 0151854124 USD SingaporeFr: 0151874494 USD SingaporeIntercompany LPQ883727905469|nan|nan|nan|nan|nan
# =========================================================================
# customer name found: CHEVRON HONG KONG
# Transaction date: '2017-10-06', Credit amount: 31482.0, Customer Name: CHEVRON HONG KONG
# 6878 invoices matches
# =========================================================================
# customer name found: OPEC
# Transaction date: '2017-10-09', Credit amount: 116186.91, Customer Name: OPEC
# 7255 invoices matches
# =========================================================================
# customer name found: ASIAPAC TRADING
# Transaction date: '2017-10-09', Credit amount: 110132.55, Customer Name: ASIAPAC TRADING
# 7255 invoices matches
# =========================================================================
# no customer name: YOUR REF =JPM091017000000|MAT DATE =10OCT17|PAY METHOD =CHECK DEPOSIT|PAYDET =D5008511|nan|nan
# =========================================================================
# customer name found: NSL OILCHEM SERVICES
# Transaction date: '2017-10-09', Credit amount: 5483.35, Customer Name: NSL OILCHEM SERVICES
# 7255 invoices matches
# =========================================================================
# no customer name: VAL DATE =06OCT17|DEPTMENT =TRADE OPERATIONSTRADE SERVICES|YOUR REF =974964454+|MAT DATE =06OCT17|ORIG PRN AMT=191633 25|PRINCIPAL =191448 25
# =========================================================================
# no customer name: REMARK =CASH CONCENTRATION TRANSFER CREDIT FROM ACCOUNT 000000400908654 TRN: 0002120730XF|nan|nan|nan|nan|nan
# =========================================================================
# customer name found: EXXONMOBIL OIL CORPORATION
# Transaction date: '2017-10-10', Credit amount: 1758038.42, Customer Name: EXXONMOBIL OIL CORPORATION
# 7438 invoices matches
# =========================================================================
# customer name found: GLENCORE SINGAPORE
# Transaction date: '2017-10-10', Credit amount: 1697355.95, Customer Name: GLENCORE SINGAPORE
# 7438 invoices matches
# invoice 78002282: amount 1696925.95 from account GLENCORE SINGAPORE due on '2017-10-10' final score: 0.999954399665
# =========================================================================
# customer name found: CUST
# Transaction date: '2017-10-10', Credit amount: 1328677.2, Customer Name: CUST
# 7438 invoices matches
# =========================================================================
# customer name found: INTER
# Transaction date: '2017-10-10', Credit amount: 1320079.5, Customer Name: INTER
# 7438 invoices matches
# =========================================================================
# customer name found: COASTAL OIL SINGAPORE
# Transaction date: '2017-10-10', Credit amount: 1105183.17, Customer Name: COASTAL OIL SINGAPORE
# 7438 invoices matches
# invoice 78012456: amount 1105183.17 from account COASTAL OIL SPORE due on '2017-10-10' final score: 0.91
# =========================================================================
# customer name found: USD
# Transaction date: '2017-10-10', Credit amount: 827534.0, Customer Name: USD
# 7438 invoices matches
# =========================================================================
# customer name found: SOUND AGENTS LIMITED
# Transaction date: '2017-10-10', Credit amount: 502322.83, Customer Name: SOUND AGENTS LIMITED
# 7438 invoices matches
# invoice 78012439: amount 502569.83 from account SOUND AGENTS LIMITED due on '2017-10-10' final score: 0.999911491182
# =========================================================================
# customer name found: COASTAL OIL SINGAPORE
# Transaction date: '2017-10-10', Credit amount: 161933.08, Customer Name: COASTAL OIL SINGAPORE
# 7438 invoices matches
# =========================================================================
# customer name found: GLENCORE SINGAPORE
# Transaction date: '2017-10-10', Credit amount: 139041.32, Customer Name: GLENCORE SINGAPORE
# 7438 invoices matches
# invoice 78012465: amount 139066.32 from account GLENCORE SINGAPORE due on '2017-10-10' final score: 0.99996763552
# =========================================================================
# customer name found: SINOPEC FUEL OIL (SINGAPORE)
# Transaction date: '2017-10-10', Credit amount: 402.0, Customer Name: SINOPEC FUEL OIL (SINGAPORE)
# 7438 invoices matches
# =========================================================================
# no customer name: YOUR REF =JPM101017000003|MAT DATE =11OCT17|PAY METHOD =CHECK DEPOSIT|PAYDET =#5005584|nan|nan
# =========================================================================
# customer name found: PREMIER TAXIS P L
# Transaction date: '2017-10-10', Credit amount: 145355.22, Customer Name: PREMIER TAXIS P L
# 7438 invoices matches
# =========================================================================
# customer name found: CHEVRON PAKISTAN LUBRICANTS(PRIVATE) LIMITED
# Transaction date: '2017-10-10', Credit amount: 4216924.18, Customer Name: CHEVRON PAKISTAN LUBRICANTS(PRIVATE) LIMITED
# 7438 invoices matches
# =========================================================================
# customer name found: AMPOL SINGAPORE TRADING
# Transaction date: '2017-10-10', Credit amount: 90390.0, Customer Name: AMPOL SINGAPORE TRADING
# 7438 invoices matches
# =========================================================================
# customer name found: CHEVRON LUBRICANTS LANKA
# Transaction date: '2017-10-10', Credit amount: 88638.23, Customer Name: CHEVRON LUBRICANTS LANKA
# 7438 invoices matches
# =========================================================================
# customer name found: CHEVRON LUBRICANTS LANKA
# Transaction date: '2017-10-10', Credit amount: 29546.08, Customer Name: CHEVRON LUBRICANTS LANKA
# 7438 invoices matches
# =========================================================================
# no customer name: REMARK =CASH CONCENTRATION BACKVALUE ADJUSTMENT CREDIT RETURN OF FUNDS FROM ACCOUNT 000000400908654 FOR 17,133,752 10 CR OF 10/10/17 TRN: 0000700730MB|nan|nan|nan|nan|nan
# =========================================================================
# no customer name: YOUR REF =17528136 / SA002|REC FROM =00000000010975001 JP MORGAN CHASE BANK SINGAPORE 17/F, CAPITAL TOWER 168 ROBINSON ROAD SINGAPORE SINGAPORE 06891-2|REMARK =/BNF/BEING PAYMENT OF YOUR REF NO 17528136/SA0022 DEBIT REF ASGSGF010941|REC GFP =10111150|nan|nan
# =========================================================================
# customer name found: GLENCORE SINGAPORE
# Transaction date: '2017-10-11', Credit amount: 999372.01, Customer Name: GLENCORE SINGAPORE
# 7620 invoices matches
# invoice 78012416: amount 719297.34 from account GLENCORE SINGAPORE due on '2017-10-11' final score: 0.949554880369
# =========================================================================
# no customer name: YOUR REF =17528063/PM0009|REC FROM =00000000010975001 JP MORGAN CHASE BANK SINGAPORE 17/F, CAPITAL TOWER 168 ROBINSON ROAD SINGAPORE SINGAPORE 06891-2|REMARK =/BNF/BEING PAYMENT UNDER YOUR REF NO 17528063/PM0009 DEBIT REF ASGSGF010906|REC GFP =10110729|nan|nan
# =========================================================================
# customer name found: SINOPEC FUEL OIL (SINGAPORE)
# Transaction date: '2017-10-11', Credit amount: 699159.36, Customer Name: SINOPEC FUEL OIL (SINGAPORE)
# 7620 invoices matches
# invoice 78012431: amount 699617.36 from account SINOPEC FUEL OIL (SINGAPORE) due on '2017-10-11' final score: 0.999882086968
# =========================================================================
# customer name found: COASTAL OIL SINGAPORE
# Transaction date: '2017-10-11', Credit amount: 131070.83, Customer Name: COASTAL OIL SINGAPORE
# 7620 invoices matches
# =========================================================================
# no customer name: YOUR REF =JPM111017000006|MAT DATE =12OCT17|PAY METHOD =CHECK DEPOSIT|PAYDET =D5005597|nan|nan
# =========================================================================
# no customer name: PAYDET =SWEEP REFTo: 0111870401 SGD SingaporeFr: 0111874478 SGD SingaporeIntercompany LPQ883728405499|nan|nan|nan|nan|nan
# =========================================================================
# customer name found: LEY CHOON CONSTRUCTIONS AND ENGINEERING
# Transaction date: '2017-10-11', Credit amount: 42744.36, Customer Name: LEY CHOON CONSTRUCTIONS AND ENGINEERING
# 7620 invoices matches
# =========================================================================
# customer name found: NSL OILCHEM SERVICES
# Transaction date: '2017-10-11', Credit amount: 8600.13, Customer Name: NSL OILCHEM SERVICES
# 7620 invoices matches
# =========================================================================
# customer name found: SG SHIPPING
# Transaction date: '2017-10-11', Credit amount: 4943.97, Customer Name: SG SHIPPING
# 7620 invoices matches
# =========================================================================
# no customer name: PAYDET =SWEEP REFTo: 0151854124 USD SingaporeFr: 0151874494 USD SingaporeIntercompany LPQ883728405455|nan|nan|nan|nan|nan
# =========================================================================
# customer name found: AMPOL SINGAPORE TRADING
# Transaction date: '2017-10-11', Credit amount: 94110.0, Customer Name: AMPOL SINGAPORE TRADING
# 7620 invoices matches
# =========================================================================
# no customer name: REMARK =CASH CONCENTRATION BACKVALUE ADJUSTMENT CREDIT RETURN OF FUNDS FROM ACCOUNT 000000400908654 FOR 2,017,122 02 CR OF 10/11/17 TRN: 0000300730MB|nan|nan|nan|nan|nan
# =========================================================================
# no customer name: YOUR REF =17528062/BS0009|REC FROM =00000000010975001 JP MORGAN CHASE BANK SINGAPORE 17/F, CAPITAL TOWER 168 ROBINSON ROAD SINGAPORE SINGAPORE 06891-2|REMARK =/BNF/BEING PAYMENT OF YOUR REF NO 17528062/BS0009 CHEVRON SINGAPORE PTE LTD| CHEVRON HOUSE 30 RAFFLES PLACE HEX 21-01 SINGAPORE 048622 DEBIT REF ASGSGF011011|REC GFP =10120217|nan|nan
# =========================================================================
# customer name found: EXXONMOBIL OIL CORPORATION
# Transaction date: '2017-10-12', Credit amount: 1584251.7, Customer Name: EXXONMOBIL OIL CORPORATION
# 7818 invoices matches
# =========================================================================
# customer name found: KAIROS OIL TRADING
# Transaction date: '2017-10-12', Credit amount: 1268349.38, Customer Name: KAIROS OIL TRADING
# 7818 invoices matches
# invoice 78010675: amount 1268394.38 from account KAIROS OIL TRADING due on '2017-10-12' final score: 0.999993613747
# =========================================================================
# customer name found: AXIS FOCUS SDN BHD SUITE
# Transaction date: '2017-10-12', Credit amount: 70901.99, Customer Name: AXIS FOCUS SDN BHD SUITE
# 7818 invoices matches
# =========================================================================
# customer name found: TZR
# Transaction date: '2017-10-12', Credit amount: 63947.92, Customer Name: TZR
# 7818 invoices matches
# =========================================================================
# no customer name: PAYDET =SWEEP REFTo: 0111870401 SGD SingaporeFr: 0111874478 SGD SingaporeIntercompany LPQ883728505487|nan|nan|nan|nan|nan
# =========================================================================
# no customer name: YOUR REF =JPM121017000004|MAT DATE =13OCT17|PAY METHOD =CHECK DEPOSIT|PAYDET =D5008512|nan|nan
# =========================================================================
# customer name found: GOLDEN OCEAN CAR CARE
# Transaction date: '2017-10-12', Credit amount: 56148.25, Customer Name: GOLDEN OCEAN CAR CARE
# 7818 invoices matches
# =========================================================================
# customer name found: CHEVRON SINGAPORE
# Transaction date: '2017-10-12', Credit amount: 210000.0, Customer Name: CHEVRON SINGAPORE
# 7818 invoices matches
# =========================================================================
# customer name found: VOLVO EAST ASIA
# Transaction date: '2017-10-12', Credit amount: 194250.92, Customer Name: VOLVO EAST ASIA
# 7818 invoices matches
# =========================================================================
# customer name found: VOLVO MALAYSIA SDN BHD FKA FEDERALAUTO INDUSTRIAL SDN BHD
# Transaction date: '2017-10-12', Credit amount: 55941.08, Customer Name: VOLVO MALAYSIA SDN BHD FKA FEDERALAUTO INDUSTRIAL SDN BHD
# 7818 invoices matches
# =========================================================================
# customer name found: CHEVRON (THAILAND ) LIMITED
# Transaction date: '2017-10-12', Credit amount: 20492.65, Customer Name: CHEVRON (THAILAND ) LIMITED
# 7818 invoices matches
# =========================================================================
# no customer name: REMARK =CASH CONCENTRATION TRANSFER CREDIT FROM ACCOUNT 000000400908654 TRN: 0001960730XF|nan|nan|nan|nan|nan
# =========================================================================
# customer name found: BE
# Transaction date: '2017-10-13', Credit amount: 3643875.49, Customer Name: BE
# 7986 invoices matches
# =========================================================================
# customer name found: SINOPEC FUEL OIL (SINGAPORE)
# Transaction date: '2017-10-13', Credit amount: 2791294.72, Customer Name: SINOPEC FUEL OIL (SINGAPORE)
# 7986 invoices matches
# =========================================================================
# customer name found: EXXONMOBIL OIL CORPORATION
# Transaction date: '2017-10-13', Credit amount: 1271636.66, Customer Name: EXXONMOBIL OIL CORPORATION
# 7986 invoices matches
# =========================================================================
# customer name found: GLENCORE SINGAPORE
# Transaction date: '2017-10-13', Credit amount: 1173669.66, Customer Name: GLENCORE SINGAPORE
# 7986 invoices matches
# invoice 78012453: amount 1173694.66 from account GLENCORE SINGAPORE due on '2017-10-13' final score: 0.999996165872
# =========================================================================
# customer name found: INTER
# Transaction date: '2017-10-13', Credit amount: 985782.26, Customer Name: INTER
# 7986 invoices matches
# =========================================================================
# customer name found: MERCURIA ENERGY TRADING
# Transaction date: '2017-10-13', Credit amount: 636172.02, Customer Name: MERCURIA ENERGY TRADING
# 7986 invoices matches
# invoice 78002259: amount 636172.02 from account MERCURIA ENERGY TRADING due on '2017-10-13' final score: 1.0
# =========================================================================
# customer name found: GLENCORE SINGAPORE
# Transaction date: '2017-10-13', Credit amount: 477151.96, Customer Name: GLENCORE SINGAPORE
# 7986 invoices matches
# invoice 78000272: amount 476721.96 from account GLENCORE SINGAPORE due on '2017-10-13' final score: 0.999837787526
# =========================================================================
# no customer name: REMARK =CASH CONCENTRATION BACKVALUE ADJUSTMENT CREDIT RETURN OF FUNDS FROM ACCOUNT 000000400908654 FOR 65,549 88 CR OF 10/12/17 TRN: 0001900730MB|nan|nan|nan|nan|nan
# =========================================================================
# no customer name: YOUR REF =17529793/BS0009|REC FROM =00000000010975001 JP MORGAN CHASE BANK SINGAPORE 17/F, CAPITAL TOWER 168 ROBINSON ROAD SINGAPORE SINGAPORE 06891-2|REMARK =/BNF/BEING PAYMENT OF YOUR REF NO 17529793/BS0009 DEBIT REF ASGSGF011469|REC GFP =10130823|nan|nan
# =========================================================================
# no customer name: REMARK =CASH CONCENTRATION BACKVALUE ADJUSTMENT CREDIT RETURN OF FUNDS FROM ACCOUNT 000000400908654 FOR 54,092 05 CR OF 10/12/17 TRN: 0001500730MB|nan|nan|nan|nan|nan
# =========================================================================
# no customer name: YOUR REF =17529749/BS0012|REC FROM =00000000010975001 JP MORGAN CHASE BANK SINGAPORE 17/F, CAPITAL TOWER 168 ROBINSON ROAD SINGAPORE SINGAPORE 06891-2|REMARK =/BNF/BEING PAYMENT OF YOUR REF NO 17529749/BS0012 DEBIT REF ASGSGF011468|REC GFP =10130838|nan|nan
# =========================================================================
# no customer name: YOUR REF =JPM131017000003|MAT DATE =16OCT17|PAY METHOD =CHECK DEPOSIT|PAYDET =D5008513|nan|nan
# =========================================================================
# customer name found: ASIAPAC TRADING
# Transaction date: '2017-10-13', Credit amount: 225861.5, Customer Name: ASIAPAC TRADING
# 7986 invoices matches
# =========================================================================
# customer name found: Singapore Petroleum
# Transaction date: '2017-10-13', Credit amount: 172010.2, Customer Name: Singapore Petroleum
# 7986 invoices matches
# =========================================================================
# customer name found: OPEC
# Transaction date: '2017-10-13', Credit amount: 102542.82, Customer Name: OPEC
# 7986 invoices matches
# =========================================================================
# customer name found: Singapore Refining Company PrivateLimited
# Transaction date: '2017-10-13', Credit amount: 51814.97, Customer Name: Singapore Refining Company PrivateLimited
# 7986 invoices matches
# =========================================================================
# customer name found: HOMETEAMNS
# Transaction date: '2017-10-13', Credit amount: 38540.0, Customer Name: HOMETEAMNS
# 7986 invoices matches
# =========================================================================
# customer name found: Volvo East Asia (Pte) Ltd
# Transaction date: '2017-10-13', Credit amount: 13692.4, Customer Name: Volvo East Asia (Pte) Ltd
# 7986 invoices matches
# =========================================================================
# customer name found: OXALIS SHIPPING CO
# Transaction date: '2017-10-13', Credit amount: 600.0, Customer Name: OXALIS SHIPPING CO
# 7986 invoices matches
# =========================================================================
# customer name found: SAFRA
# Transaction date: '2017-10-13', Credit amount: 360.0, Customer Name: SAFRA
# 7986 invoices matches
# =========================================================================
# no customer name: PAYDET =SWEEP REFTo: 0151854124 USD SingaporeFr: 0151874494 USD SingaporeIntercompany LPQ883728605473|nan|nan|nan|nan|nan
# =========================================================================
# customer name found: GS CALTEX CORPORATIONGS TOWER
# Transaction date: '2017-10-13', Credit amount: 114943.28, Customer Name: GS CALTEX CORPORATIONGS TOWER
# 7986 invoices matches
# =========================================================================
# customer name found: SINGAPORE REFINING COMPANY
# Transaction date: '2017-10-13', Credit amount: 96602.56, Customer Name: SINGAPORE REFINING COMPANY
# 7986 invoices matches
# =========================================================================
# customer name found: CHEVRON (CHINA) INVESTMENT CO LTUNIT
# Transaction date: '2017-10-13', Credit amount: 13022.08, Customer Name: CHEVRON (CHINA) INVESTMENT CO LTUNIT
# 7986 invoices matches
# =========================================================================
# customer name found: SGACU
# Transaction date: '2017-10-16', Credit amount: 4614178.78, Customer Name: SGACU
# 6303 invoices matches
# =========================================================================
# customer name found: EXXONMOBIL OIL CORPORATION
# Transaction date: '2017-10-16', Credit amount: 2287201.54, Customer Name: EXXONMOBIL OIL CORPORATION
# 6303 invoices matches
# =========================================================================
# customer name found: SGACU
# Transaction date: '2017-10-16', Credit amount: 2270509.34, Customer Name: SGACU
# 6303 invoices matches
# =========================================================================
# no customer name: REMARK =CASH CONCENTRATION BACKVALUE ADJUSTMENT CREDIT RETURN OF FUNDS FROM ACCOUNT 000000400908654 FOR 1,841,063 48 CR OF 10/13/17 TRN: 0001100730MB|nan|nan|nan|nan|nan
# =========================================================================
# no customer name: YOUR REF =17528169 /BS0012|REC FROM =00000000010975001 JP MORGAN CHASE BANK SINGAPORE 17/F, CAPITAL TOWER 168 ROBINSON ROAD SINGAPORE SINGAPORE 06891-2|REMARK =/BNF/BEING PAYMENT OF YOUR REF NO 17528169/BS0012 DEBIT REF ASGSGF011027|REC GFP =10161051|nan|nan
# =========================================================================
# customer name found: HIN HIN TRADING
# Transaction date: '2017-10-16', Credit amount: 1188079.22, Customer Name: HIN HIN TRADING
# 6303 invoices matches
# invoice 78000298: amount 893700.0 from account HIN HIN TRADING due on '2017-10-16' final score: 0.955400061959
# =========================================================================
# no customer name: REMARK =CASH CONCENTRATION BACKVALUE ADJUSTMENT CREDIT FROM ACCOUNT 000000400908654 FOR 763,139 08 CR OF 09/13/17 TRN: 0000700730MB|nan|nan|nan|nan|nan
# =========================================================================
# customer name found: COMPENSATION DEPT
# Transaction date: '2017-10-16', Credit amount: 763139.08, Customer Name: COMPENSATION DEPT
# 6303 invoices matches
# =========================================================================
# customer name found: UTUSAN MEWAH SDN BHD NO
# Transaction date: '2017-10-16', Credit amount: 155000.0, Customer Name: UTUSAN MEWAH SDN BHD NO
# 6303 invoices matches
# =========================================================================
# no customer name: REMARK =CASH CONCENTRATION BACKVALUE ADJUSTMENT CREDIT RETURN OF FUNDS FROM ACCOUNT 000000400908654 TRN: 0002300730MB|nan|nan|nan|nan|nan
# =========================================================================
# no customer name: PAYDET =SWEEP REFTo: 0111870401 SGD SingaporeFr: 0111874478 SGD SingaporeIntercompany LPQ883728906252|nan|nan|nan|nan|nan
# =========================================================================
# no customer name: YOUR REF =JPM161017000004|MAT DATE =17OCT17|PAY METHOD =CHECK DEPOSIT|PAYDET =D5007560|nan|nan
# =========================================================================
# customer name found: BUKIT BATOK DRIVING CENTRE
# Transaction date: '2017-10-16', Credit amount: 36283.93, Customer Name: BUKIT BATOK DRIVING CENTRE
# 6303 invoices matches
# =========================================================================
# customer name found: HSBC
# Transaction date: '2017-10-16', Credit amount: 11417.26, Customer Name: HSBC
# 6303 invoices matches
# =========================================================================
# customer name found: JURONG BARRELS & DRUMS IND
# Transaction date: '2017-10-16', Credit amount: 4986.2, Customer Name: JURONG BARRELS & DRUMS IND
# 6303 invoices matches
# =========================================================================
# customer name found: NSL OILCHEM SERVICES
# Transaction date: '2017-10-16', Credit amount: 3453.96, Customer Name: NSL OILCHEM SERVICES
# 6303 invoices matches
# =========================================================================
# customer name found: SG SHIPPING
# Transaction date: '2017-10-16', Credit amount: 2706.17, Customer Name: SG SHIPPING
# 6303 invoices matches
# =========================================================================
# customer name found: CHEVRON ORONITE
# Transaction date: '2017-10-16', Credit amount: 30610.51, Customer Name: CHEVRON ORONITE
# 6303 invoices matches
# =========================================================================
# customer name found: EXXONMOBIL OIL CORPORATION
# Transaction date: '2017-10-17', Credit amount: 3615038.74, Customer Name: EXXONMOBIL OIL CORPORATION
# 6530 invoices matches
# =========================================================================
# customer name found: CUST
# Transaction date: '2017-10-17', Credit amount: 1355572.01, Customer Name: CUST
# 6530 invoices matches
# =========================================================================
# customer name found: INTER
# Transaction date: '2017-10-17', Credit amount: 988814.68, Customer Name: INTER
# 6530 invoices matches
# =========================================================================
# customer name found: AXIS FOCUS SDN BHD SUITE
# Transaction date: '2017-10-17', Credit amount: 70851.72, Customer Name: AXIS FOCUS SDN BHD SUITE
# 6530 invoices matches
# =========================================================================
# no customer name: REMARK =CASH CONCENTRATION BACKVALUE ADJUSTMENT CREDIT FROM ACCOUNT 000000400908654 TRN: 0002400730MB|nan|nan|nan|nan|nan
# =========================================================================
# no customer name: YOUR REF =JPM171017000003|MAT DATE =19OCT17|PAY METHOD =CHECK DEPOSIT|PAYDET =D5005599|nan|nan
# =========================================================================
# customer name found: MPT OIL
# Transaction date: '2017-10-17', Credit amount: 200000.0, Customer Name: MPT OIL
# 6530 invoices matches
# =========================================================================
# customer name found: UNIVERSAL CONSULTANT
# Transaction date: '2017-10-17', Credit amount: 85600.0, Customer Name: UNIVERSAL CONSULTANT
# 6530 invoices matches
# =========================================================================
# customer name found: UNIX LINE
# Transaction date: '2017-10-17', Credit amount: 4500.0, Customer Name: UNIX LINE
# 6530 invoices matches
# =========================================================================
# customer name found: SG SHIPPING
# Transaction date: '2017-10-17', Credit amount: 3571.36, Customer Name: SG SHIPPING
# 6530 invoices matches
# =========================================================================
# no customer name: PAYDET =SWEEP REFTo: 0151854124 USD SingaporeFr: 0151874494 USD SingaporeIntercompany LPQ883729005457|nan|nan|nan|nan|nan
# =========================================================================
# customer name found: TAIKO ACID WORKS SDN BHDNO
# Transaction date: '2017-10-17', Credit amount: 39504.19, Customer Name: TAIKO ACID WORKS SDN BHDNO
# 6530 invoices matches
# =========================================================================
# customer name found: FUCHS LUBRICANTS(INDIA) PVT
# Transaction date: '2017-10-17', Credit amount: 17992.33, Customer Name: FUCHS LUBRICANTS(INDIA) PVT
# 6530 invoices matches
# =========================================================================
# no customer name: REMARK =CASH CONCENTRATION TRANSFER CREDIT FROM ACCOUNT 000000400908654 TRN: 0001860730XF|nan|nan|nan|nan|nan
# =========================================================================
# customer name found: GLENCORE SINGAPORE
# Transaction date: '2017-10-18', Credit amount: 1814315.28, Customer Name: GLENCORE SINGAPORE
# 7590 invoices matches
# =========================================================================
# customer name found: TF
# Transaction date: '2017-10-18', Credit amount: 1579399.27, Customer Name: TF
# 7590 invoices matches
# =========================================================================
# customer name found: KAIROS OIL TRADING
# Transaction date: '2017-10-18', Credit amount: 352108.05, Customer Name: KAIROS OIL TRADING
# 7590 invoices matches
# invoice 78012466: amount 352583.05 from account KAIROS OIL TRADING due on '2017-10-18' final score: 0.99975717681
# =========================================================================
# customer name found: SINOPEC FUEL OIL (SINGAPORE)
# Transaction date: '2017-10-19', Credit amount: 2248137.95, Customer Name: SINOPEC FUEL OIL (SINGAPORE)
# 6812 invoices matches
# invoice 78002287: amount 1209205.84 from account SINOPEC FUEL OIL (SINGAPORE) due on '2017-10-19' final score: 0.916816590459
# invoice 78012457: amount 1039820.11 from account SINOPEC FUEL OIL (SINGAPORE) due on '2017-10-19' final score: 0.903254508381
# =========================================================================
# no customer name: REMARK =CASH CONCENTRATION BACKVALUE ADJUSTMENT CREDIT RETURN OF FUNDS FROM ACCOUNT 000000400908654 FOR 2,059,791 39 CR OF 10/18/17 TRN: 0001900730MB|nan|nan|nan|nan|nan
# =========================================================================
# no customer name: YOUR REF =17528846/9423/94|REC FROM =00000000010975001 JP MORGAN CHASE BANK SINGAPORE 17/F, CAPITAL TOWER 168 ROBINSON ROAD SINGAPORE SINGAPORE 06891-2|REMARK =/BNF/BEING PAYMENT UNDER YOUR REF NO 17528846/9423/9425/PA0004/CHE VRON SINGAPORE PTE LTD| CHEVRON HO USE, 30 RAFFLES PLACE HEX 21-01 S INGAPORE 048622(COMPANY REGISTRAT ION NO : 199206695E) DEBIT REF ASGSGF011423|REC GFP =10191022|nan|nan
# =========================================================================
# customer name found: EXXONMOBIL OIL CORPORATION
# Transaction date: '2017-10-19', Credit amount: 1512593.14, Customer Name: EXXONMOBIL OIL CORPORATION
# 6812 invoices matches
# =========================================================================
# customer name found: FRATELLI COSULICH BUNKERS (S)
# Transaction date: '2017-10-19', Credit amount: 664161.22, Customer Name: FRATELLI COSULICH BUNKERS (S)
# 6812 invoices matches
# invoice 78000269: amount 663766.22 from account FRATELLI COSULICH BUNKERS due on '2017-10-19' final score: 0.909892947679
# =========================================================================
# no customer name: YOUR REF =JPM191017000004|MAT DATE =20OCT17|PAY METHOD =CHECK DEPOSIT|PAYDET =D5005600|nan|nan
# =========================================================================
# customer name found: ASIAPAC TRADING
# Transaction date: '2017-10-19', Credit amount: 137731.41, Customer Name: ASIAPAC TRADING
# 6812 invoices matches
# =========================================================================
# customer name found: PREMIER TAXIS P L
# Transaction date: '2017-10-19', Credit amount: 134377.02, Customer Name: PREMIER TAXIS P L
# 6812 invoices matches
# =========================================================================
# customer name found: OPEC
# Transaction date: '2017-10-19', Credit amount: 108030.73, Customer Name: OPEC
# 6812 invoices matches
# =========================================================================
# no customer name: YOUR REF =JPM191017000004|MAT DATE =20OCT17|PAY METHOD =CHECK DEPOSIT|PAYDET =OCBC001117|nan|nan
# =========================================================================
# customer name found: OCBC GROUP ACCOUNTS
# Transaction date: '2017-10-19', Credit amount: 2140.0, Customer Name: OCBC GROUP ACCOUNTS
# 6812 invoices matches
# =========================================================================
# no customer name: PAYDET =SWEEP REFTo: 0151854124 USD SingaporeFr: 0151874494 USD SingaporeIntercompany LPQ883729206542|nan|nan|nan|nan|nan
# =========================================================================
# customer name found: MITSUI N CO (ASIA PACIFIC)
# Transaction date: '2017-10-19', Credit amount: 398983.02, Customer Name: MITSUI N CO (ASIA PACIFIC)
# 6812 invoices matches
# =========================================================================
# customer name found: CHEVRON LUBRICANTS VIETNAM LIMITEDDINH VU INDUSTRIAL PARKHAI PHONG CITY VIETNAM
# Transaction date: '2017-10-19', Credit amount: 145859.8, Customer Name: CHEVRON LUBRICANTS VIETNAM LIMITEDDINH VU INDUSTRIAL PARKHAI PHONG CITY VIETNAM
# 6812 invoices matches
# =========================================================================
# customer name found: AMPOL SINGAPORE TRADING
# Transaction date: '2017-10-19', Credit amount: 142280.0, Customer Name: AMPOL SINGAPORE TRADING
# 6812 invoices matches
# =========================================================================
# customer name found: CHEVRON HONG KONG
# Transaction date: '2017-10-19', Credit amount: 129164.27, Customer Name: CHEVRON HONG KONG
# 6812 invoices matches
# =========================================================================
# customer name found: CHEVRON (THAILAND ) LIMITED
# Transaction date: '2017-10-19', Credit amount: 113131.76, Customer Name: CHEVRON (THAILAND ) LIMITED
# 6812 invoices matches
# =========================================================================
# customer name found: TEXAS PETROCHEMICAL ASIA PACIFIC
# Transaction date: '2017-10-19', Credit amount: 109341.48, Customer Name: TEXAS PETROCHEMICAL ASIA PACIFIC
# 6812 invoices matches
# =========================================================================
# customer name found: ENVIRON SPECIALITY CHEMICALS P
# Transaction date: '2017-10-19', Credit amount: 19523.75, Customer Name: ENVIRON SPECIALITY CHEMICALS P
# 6812 invoices matches
# invoice 974975737: amount 19137.73 from account ENVIRON SPECIALITY CHEMICALS PVT. due on '2017-10-19' final score: 0.906441073052
# =========================================================================
# customer name found: FUCHS LUBRICANTS(INDIA) PVT
# Transaction date: '2017-10-19', Credit amount: 17951.33, Customer Name: FUCHS LUBRICANTS(INDIA) PVT
# 6812 invoices matches
# invoice 14002676: amount 17992.33 from account FUCHS LUBRICANTS (INDIA) PVT.. due on '2017-10-19' final score: 0.973874602686
# =========================================================================
# customer name found: VIETNAM LUBRICANTS AND CHEMICALSJ
# Transaction date: '2017-10-19', Credit amount: 16512.85, Customer Name: VIETNAM LUBRICANTS AND CHEMICALSJ
# 6812 invoices matches
# =========================================================================
# customer name found: INTER
# Transaction date: '2017-10-20', Credit amount: 1642522.68, Customer Name: INTER
# 7007 invoices matches
# =========================================================================
# customer name found: H HIN HIN TRADING
# Transaction date: '2017-10-20', Credit amount: 1559020.0, Customer Name: H HIN HIN TRADING
# 7007 invoices matches
# invoice 78002253: amount 1309472.11 from account HIN HIN TRADING due on '2017-10-20' final score: 0.911187912791
# invoice 78012513: amount 1495036.47 from account HIN HIN TRADING due on '2017-10-20' final score: 0.932612644225
# =========================================================================
# customer name found: TF
# Transaction date: '2017-10-20', Credit amount: 1404124.5, Customer Name: TF
# 7007 invoices matches
# customer names found: 147
# customer names not found: 53
# final match count: 33

# %%
pd_matched = pd.DataFrame(matches)[['Bank acc','Bank date','Bank amt','Invoice acc','Invoice due','Invoice amt','Name score',\
                       'Date score','Amount score','Final score']]

write_to_excel(pd_matched,"matched_transactions.xls")

# %%
set(lst_customer)
# Out:
# {'AEGEAN MARINE PETROLEUM NETWORK IN',
#  'AKR CORPORINDO PT',
#  'ALLIANCE CONCRETE',
#  'AMAZE CARCARE SERVICES PTE LTD',
#  'AMERICAN EXPRESS INTERNATIONAL INC',
#  'AMPOL SINGAPORE TRADING PTE LTD',
#  'ANZ SG',
#  'ARC ENERGY TRADING PTE LTD',
#  'ASIAPAC TRADING PTE LTD',
#  'AXIS FOCUS SDN BHD SUITE',
#  'AXS PTE LTD',
#  'BE',
#  'BILSEA INTERNATIONAL PTE LTD',
#  'BLACKHEM (M) SDN BHD UNIT NO',
#  'BP INTERNATIONAL LTD',
#  'BRIGHTOIL PETROLEUM (SPORE) PTE LTD',
#  'BTS TANKERS PTE LIMITEDMAYBANK TOWER',
#  'BUKIT BATOK DRIVING CENTRE LTD',
#  'CABINDA GULF OIL COMPANY LIMITED',
#  'CALTEX AUSTRALIA LIMITED TREASURY OPERATIONS LVL',
#  'CH',
#  'CHASSGSG',
#  'CHEMOIL INTERNATIONALPTE LTD',
#  'CHEV MARINE PRODUCTS LLC',
#  'CHEVRON (CHINA) INVESTMENT CO LTUNIT',
#  'CHEVRON (THAILAND ) LIMITED',
#  'CHEVRON (TIANJIN) LUBRICANTS CONO',
#  'CHEVRON CAMBODIA LIMITED',
#  'CHEVRON HOLDINGS INC',
#  'CHEVRON HOLDINGS INC TAIWAN BRANCH',
#  'CHEVRON HONG KONG LTD',
#  'CHEVRON INTERNATIONAL OIL CO',
#  'CHEVRON INTERNATIONAL PTE LTD',
#  'CHEVRON LUBRICANTS LANKA PLC',
#  'CHEVRON LUBRICANTS VIETNAM LIMITEDDINH VU INDUSTRIAL PARKHAI PHONG CITY VIETNAM',
#  'CHEVRON MALAYSIA LIMITED',
#  'CHEVRON MALAYSIA LIMITED MALAYSIA DOMI MALAYSIA NATO MALAYSIA',
#  'CHEVRON ORONITE PTE LTD',
#  'CHEVRON PAKISTAN LUBRICANTS(PRIVATE) LIMITED',
#  'CHEVRON PHILIPPINES INC',
#  'CHEVRON PRODUCTS COMPANY',
#  'CHEVRON SERVICES COMPANY',
#  'CHEVRON SHIPPING COMPANY LLC',
#  'CHEVRON SINGAPORE PTE LTD',
#  'CHEVRON THAILAND NGD HOLDING',
#  'CHEVRON TRADING PTE LTD',
#  'CHEVRON TRANSPORT CORPORATION',
#  'CHEVRON USA INC (SG BR)',
#  'CHEVRON USA SINGAPORE BRANCH',
#  'CHIMBUSCO PAN NATION PETRO',
#  'CHOP YEW LEE ENERGY SDN BHD',
#  'CHV INT',
#  'CHVMARINEPRODUCTLLC',
#  'COASTAL OIL SINGAPORE PTE LTD',
#  'COMPENSATION DEPT',
#  'CUSA SINGAPORE BR',
#  'CUST',
#  'DBS INTERNET BANKING',
#  'DEKA SINGAPORE RAFFL',
#  'DK',
#  'ENEOS ITALSING PTE LTD',
#  'ENERGETIC MARKETING PTE LTD',
#  'ENVIRON SPECIALITY CHEMICALS P LTD',
#  'EQUATORIAL MARINE FUEL MANAGEMENT SERVICES PTE LTD',
#  'EVONIK METHIONINE SEA PTE LTD',
#  'EVONIK METHIONINESEA PTE LTD',
#  'EVONIK OIL ADDITIVES ASIA PACIFIC',
#  'EXXONMOBIL CHEMICAL ASIA PACIFIC (A',
#  'EXXONMOBIL OIL CORPORATION',
#  'F',
#  'FLEXSYS CHEMICALS(M) SDN BHDLOT',
#  'FRATELLI COSULICH BUNKERS (S) PTE LTD',
#  'FUCHS LUBRICANTS INDIA PVT LTD',
#  'FUCHS LUBRICANTS(INDIA) PVT LTD',
#  'GAC (SINGAPORE) PTE LTD',
#  'GB',
#  'GLENCORE SINGAPORE PTE LTD',
#  'GLENCORE SINGAPORE PTELTD',
#  'GOLDBELL ENGINEERING',
#  'GOLDEN OCEAN CAR CARE',
#  'GS CALTEX CORPORATION GS TOWER',
#  'GS CALTEX CORPORATION YEOKSAM',
#  'GS CALTEX CORPORATIONGS TOWER',
#  'GS CALTEX CORPORATIONYEOKSAM',
#  'GTL AGENCIES (S) PRIVATE LIMITED',
#  'H HIN HIN TRADING PTE LTD',
#  'HIN HIN TRADING PRIVATE LIMITED',
#  'HIN HIN TRADING PTE LTD',
#  'HOCK SENG HENG TRANSPORT ANDTRADING PL NO',
#  'HOCK SENG HENG TRANSPORT ANDTRADING PTE LTD',
#  'HOMETEAMNS',
#  'HONG KONG INTERNATIONAL CAPITAL LTD',
#  'HSBC LTD',
#  'IC NO',
#  'ID NO',
#  'INCHCAPE SHIPPING SERVICES (S) P L',
#  'INTER',
#  'INTER TERMINAL SERVICES',
#  'IPTISAN SDN BHD',
#  'IRAS',
#  'JSSPL PORT AGENCIES',
#  'JURONG BARRELS & DRUMS IND PTE LTD',
#  'JXTG NIPPON OIL AND ENERGY CORPORATION',
#  'KAIROS OIL TRADING',
#  'KIM TIONG ENTERPRISES PTE LTD',
#  'LEY CHOON CONSTRUCTIONS AND ENGINEERING PTE LTD',
#  'LINDE GAS SINGAPORE PTE LTD',
#  'LUBRIZOL SOUTHEAST ASIA PTE LTD',
#  'MAPTRASCO DATE OF REG',
#  'MERCURIA ENERGY TRADING PTE LTD',
#  'MING HUP TRADING PTE LTD',
#  'MITSUI N CO (ASIA PACIFIC) PTE LTD',
#  'MPA',
#  'MPT OIL PTE LTD',
#  'MULTICO MARKETING AND SERVICES PTELTD',
#  'NETS (S) Pte Ltd',
#  'NEWOCEAN FUEL (SINGAPORE) PTE LTD',
#  'NL',
#  'NOMURA JIMUSHO INC',
#  'NSL FUEL MANAGEMENT SERVICES PTE LTD',
#  'NSL OILCHEM SERVICES',
#  'OCBC GROUP ACCOUNTS',
#  'OPEC PTE LTD',
#  'OXALIS SHIPPING CO PTE LTD',
#  'P',
#  'PETROLIAM NASIONAL BERHAD (PETRONAS)',
#  'PETROTRADE PHILIPPINES INC',
#  'PHILIP MORRIS SINGAPORE PTE LTD',
#  'PREMIER TAXIS P L',
#  'PT CHEVRON OIL PRODUCTS INDONESIA',
#  'PT CHEVRON PACIFIC INDONESIAGEDUNG SENTRAL SENAYAN I FL',
#  'PT MULTI TRADING PRATAMA JL LURE NO',
#  'PT NUSARAYA PUTRA MANDIRI',
#  'PTT INTERNATIONAL TRADING PTE LTD',
#  'PTT PUBLIC COMPANY LIMITED',
#  'QASTALANI S',
#  'QASTALANI SDN BHD',
#  'QASTALANI SDN BHD NO',
#  'S OIL',
#  'SAFRA',
#  'SAMBO E&C CO LTD',
#  'SAMWOH CORPORATION',
#  'SENTEK MARINE N TRADING PTE LTD',
#  'SENTEK MARINE TRADING P L DATE OF REG',
#  'SENTEK MARINE TRADING PTE LTD',
#  'SFC EXCELLENCE CO',
#  'SG SHIPPING PTE LTD',
#  'SGACU',
#  'SGD',
#  'SHELL EASTERN PETROLEUM (PTE) LIMIT',
#  'SHELL EASTERN TRADING (PRIVATE)',
#  'SINGAPORE PETROLEUM COMPANY LTD',
#  'SINGAPORE REFINING COMPANY PTE LTD',
#  'SINOPEC FUEL OIL (SINGAPORE) PTE LTD',
#  'SINOPEC LUBRICANT (SG) PTE LTD',
#  'SK ENERGY INTERNATIONAL PTE LTD',
#  'SOUND AGENTS LIMITED',
#  'SOUND AGENTS LIMITED ADD',
#  'SOUND AGENTS LTD',
#  'SPORE POST LTD',
#  'STAMFORD AMERICAN INTERNATIONAL SCH PL',
#  'STAR PETROLEUM REFINING COMPANY LTD',
#  'STELLA CHEMIFA SINGAPORE PTE LTD',
#  'Siltronic Singapore Pte Ltd',
#  'Singapore Petroleum',
#  'Singapore Refining Company PrivateLimited',
#  'TAIKO ACID WORKS SDN BHDNO',
#  'TEN & HAN TRADING PTE LTD',
#  'TEXAS PETROCHEMICAL ASIA PACIFICPTE LTD',
#  'TF',
#  'TOTAL OIL ASIA',
#  'TOYOTA TSUSHO PETROLEUM PTE LTD',
#  'TZR',
#  'UNIVERSAL CONSULTANTPTE LTD',
#  'UNIX LINE PTE LTD',
#  'USD',
#  'UTUSAN MEWAH SDN BHD',
#  'UTUSAN MEWAH SDN BHD NO',
#  'VIETNAM LUBRICANTS AND CHEMICALJSC',
#  'VIETNAM LUBRICANTS AND CHEMICALSJ',
#  'VIETSEA COMPANY PTE LTD',
#  'VOLVO EAST ASIA PTE LTD',
#  'VOLVO MALAYSIA SDN BHD FKA FEDERALAUTO INDUSTRIAL SDN BHD',
#  'Volvo East Asia (Pte) Ltd',
#  'WANA INDAH ASRI JL KOMPLEK LANDMARK DELTA C NO',
#  'WANA INDAH ASRI KOMPLEK LANDMARK DELTA C',
#  'Z ENERGY LTD'}

# %%
for index,row in bank_1[:3].iterrows():
    print "========================================================================="
    remarks = row['Remarks 1']+row['Remarks 2']+row['Remarks 3']+row['Remarks 4']+row['Remarks 5']
    match_result = re.match(r".*=PRESENTER REF.(\d+).*",remarks)
    if match_result==None:
        print remarks 
        print row["Credit Amount"]
    else:
        ref = match_result.group(1)
        print"reference number found: "+ref
        print "invoice matched: " 
        for inv in invoice_1[invoice_1.Reference==ref].to_dict('records'):
            print inv
# Out:
# =========================================================================
# reference number found: 17526719
# invoice matched:
# {u'Company Code': 4189, u'Clearing Document': '14002650', u'Account': 8217247, u'Reference': '17526719', u'Net due date': Timestamp('2017-10-02 00:00:00'), u'Text': u'Jaya Ocean-20170904-Asphalt BTB  2017-08Aug', u'Local currency 2': u'USD', u'Baseline Payment Dte': Timestamp('2017-10-02 00:00:00'), u'User name': u'XI_PC8008', u'Local Currency': u'USD', u'Document Number': '78000256', u'Amount in loc.curr.2': 1072563.46, u'Account Name': u'HIN HIN TRADING PTE LTD', u'Amount in doc. curr.': 1072563.46, u'Document Date': Timestamp('2017-09-04 00:00:00'), u'Document currency': u'USD', u'Clearing date': Timestamp('2017-10-02 00:00:00'), u'Amount in local currency': 1072563.46, u'Posting Date': Timestamp('2017-09-01 00:00:00')}
# =========================================================================
# YOUR REF    =O/B DBTCO AMERICREC FROM    =DEUTSCHE BANK TRUST COMPANY AMERICAS 60 WALL STREET NEW YORK NYB/O CUSTOMER=/2016806055 GLENCORE SINGAPORE PTE LTD-BUNKER AND SEC 1 TEMASEK AVENUE 34-01 MILLENIA TOWERB/O BANK    =/04411229 DEUTSCHE BANK AG AT:BANKING AND CASH OPERATIONS ONE RAFFLES QUAY, 15-00 SOUTH TOWERSINGAPORE 048583 SINGAPOREREMARK      =17527857, 17527858, 17527860 DEBIT REF 092817409846
# 927560.58
# =========================================================================
# YOUR REF    =1IR710024595C01REC FROM    =THE BANK OF NEW YORK MELLON 225 LIBERTY STREET NEW YORK NY 10005-2901B/O CUSTOMER=/4519015182 MERCURIA ENERGY TRADING PTE LTD 12 MARINA VIEW,ASIA SQUARE TOWER 2,26-01,SINGAPORE 018961, SINGAPOREB/O BANK    =UNITED OVERSEAS BANK LTD GOH SHUH HUA GFCS GF ENTITY REPORT N CTRL 156 CECIL STREET 06 06 FAR SINGAPORE SINGAPORE 06954-4REMARK      =1208312 17528773 DEBIT REF F9S1710027581100
# 629371.84

# %%
m = re.match(r".*=PRESENTER REF.(\d+).*", "REMARK      =PRESENTER REF.17526719/HH007 /CHGS/USD25,00/ DEBIT REF 550-01-0223512")
m.group(1)
# Out:
# '17526719'

# %%
invoice_1[(invoice_1['Local Currency']=='USD') & (invoice_1['Amount in local currency']==1072538.46)]
# Out:
# Empty DataFrame
# Columns: [Account, Account Name, Reference, Document Number, Text, User name, Company Code, Posting Date, Document Date, Baseline Payment Dte, Net due date, Document currency, Amount in doc. curr., Local Currency, Amount in local currency, Local currency 2, Amount in loc.curr.2, Clearing date, Clearing Document]
# Index: []

# %%
set_invoice_ref = set(invoice_uncleared['Reference'].dropna().values)
set_bank_cust_ref = set(bank['Customer Reference'].dropna().values)
print "There are {0} unique ref. in the invoices".format(len(set_invoice_ref))
print "There are {0} unique customer ref. in the bank statements".format(len(set_bank_cust_ref))

print " {0:.2%} customers put invoice reference number in bank statements".format(len(set_bank_cust_ref)*1.0/len(set_invoice_ref))
# Out:
# There are 5096 unique ref. in the invoices
# There are 680 unique customer ref. in the bank statements
#  13.34% customers put invoice reference number in bank statements

# %%
def is_ref_exists(invoice_ref, cust_ref_set):
    return True in (invoice_ref in str(cust_ref) for cust_ref in cust_ref_set)

# %%
for ref in invoice['Document Number'].dropna().values:
    if is_ref_exists(str(ref),set_bank_cust_ref):
        print str(ref)
# Out:
# 100060033
# 974972375
# 100060033
# 974964454
# 974968939
# 974972149
# 974977299
# 974981952
# 974984453
# 30000225
# 30000291

# %%
inv = invoice_uncleared[['Account Name','Amount in doc. curr.']]

# %%
bk = bank[['Credit Amount','Remarks 3']].dropna()

# %%
pd.merge(inv,bk,how="inner",left_on='Amount in doc. curr.',right_on='Credit Amount')
# Out:
#                             Account Name  Amount in doc. curr.  Credit Amount  \
# 0                  Z ENERGY 2015 LIMITED              25280.00       25280.00
# 1                VIETSEA COMPANY PTE LTD                600.00         600.00
# 2                VIETSEA COMPANY PTE LTD                600.00         600.00
# 3                VIETSEA COMPANY PTE LTD                600.00         600.00
# 4                VIETSEA COMPANY PTE LTD                600.00         600.00
# 5                VIETSEA COMPANY PTE LTD                600.00         600.00
# 6              STANDARD MARITIME PTE LTD                600.00         600.00
# 7              STANDARD MARITIME PTE LTD                600.00         600.00
# 8              STANDARD MARITIME PTE LTD                600.00         600.00
# 9              STANDARD MARITIME PTE LTD                600.00         600.00
# 10             STANDARD MARITIME PTE LTD                600.00         600.00
# 11                  S5 ASIA PTE. LIMITED                600.00         600.00
# 12                  S5 ASIA PTE. LIMITED                600.00         600.00
# 13                  S5 ASIA PTE. LIMITED                600.00         600.00
# 14                  S5 ASIA PTE. LIMITED                600.00         600.00
# 15                  S5 ASIA PTE. LIMITED                600.00         600.00
# 16    RAYSUN SHIPPING LINES AGENCIES PTE                600.00         600.00
# 17    RAYSUN SHIPPING LINES AGENCIES PTE                600.00         600.00
# 18    RAYSUN SHIPPING LINES AGENCIES PTE                600.00         600.00
# 19    RAYSUN SHIPPING LINES AGENCIES PTE                600.00         600.00
# 20    RAYSUN SHIPPING LINES AGENCIES PTE                600.00         600.00
# 21             KINGSTATE MARITIME AGENCY                600.00         600.00
# 22             KINGSTATE MARITIME AGENCY                600.00         600.00
# 23             KINGSTATE MARITIME AGENCY                600.00         600.00
# 24             KINGSTATE MARITIME AGENCY                600.00         600.00
# 25             KINGSTATE MARITIME AGENCY                600.00         600.00
# 26    INCHCAPE SHIPPING SERVICES (S) P L                600.00         600.00
# 27    INCHCAPE SHIPPING SERVICES (S) P L                600.00         600.00
# 28    INCHCAPE SHIPPING SERVICES (S) P L                600.00         600.00
# 29    INCHCAPE SHIPPING SERVICES (S) P L                600.00         600.00
# ..                                   ...                   ...            ...
# 496        EVONIK METHIONINE SEA PTE LTD               4213.13        4213.13
# 497        ENERGETIC MARKETING PTE. LTD.             202500.00      202500.00
# 498               ENEOS ITALSING PTE LTD              19525.31       19525.31
# 499               ENEOS ITALSING PTE LTD              19525.31       19525.31
# 500   EASTMAN CHEMICAL SINGAPORE PTE LTD            3165506.78     3165506.78
# 501            Chevron Trading Pte. Ltd.           14788586.63    14788586.63
# 502          CHEVRON SINGAPORE PTE. LTD.             253834.28      253834.28
# 503          CHEVRON SINGAPORE PTE. LTD.             590762.04      590762.04
# 504             Chevron Oronite Pte Ltd.              40518.52       40518.52
# 505   Chevron Lubricants Vietnam Limited              38472.18       38472.18
# 506            Chevron Hong Kong Limited              35516.60       35516.60
# 507            Chevron Hong Kong Limited              54054.00       54054.00
# 508            Chevron Hong Kong Limited              34250.60       34250.60
# 509            Chevron Hong Kong Limited              46618.00       46618.00
# 510            Chevron Hong Kong Limited              26906.00       26906.00
# 511            Chevron Hong Kong Limited              26906.00       26906.00
# 512  Chevron (Thailand) Limited – Branch              17812.71       17812.71
# 513   CALTEX AUSTRALIA PETROLEUM PTY LTD             115746.60      115746.60
# 514                 BP SINGAPORE PTE LTD            2613745.27     2613745.27
# 515         BILSEA INTERNATIONAL PTE LTD            1372981.39     1372981.39
# 516         BILSEA INTERNATIONAL PTE LTD            2095299.96     2095299.96
# 517            AUSTRALIA AND NEW ZEALAND                378.30         378.30
# 518           ARC ENERGY TRADING PTE LTD           11336736.19    11336736.19
# 519      AMPOL SINGAPORE TRADING PTE LTD              13688.89       13688.89
# 520      AMPOL SINGAPORE TRADING PTE LTD              13688.89       13688.89
# 521   AMPOL PROCUREMENT SERVICES PTE LTD             154100.00      154100.00
# 522   AMPOL PROCUREMENT SERVICES PTE LTD              49540.00       49540.00
# 523   AMPOL PROCUREMENT SERVICES PTE LTD              23628.80       23628.80
# 524   AMPOL PROCUREMENT SERVICES PTE LTD              23628.80       23628.80
# 525   AMPOL PROCUREMENT SERVICES PTE LTD              13400.00       13400.00
#
#                                              Remarks 3
# 0    B/O CUSTOMER=Z ENERGY LTD3 QUEENS WHARF, WELLI...
# 1                          PAY METHOD  =INTERBANK GIRO
# 2    B/O CUSTOMER=BTS TANKERS PTE LIMITEDMAYBANK TO...
# 3                          PAY METHOD  =INTERBANK GIRO
# 4                          PAY METHOD  =INTERBANK GIRO
# 5                          PAY METHOD  =INTERBANK GIRO
# 6                          PAY METHOD  =INTERBANK GIRO
# 7    B/O CUSTOMER=BTS TANKERS PTE LIMITEDMAYBANK TO...
# 8                          PAY METHOD  =INTERBANK GIRO
# 9                          PAY METHOD  =INTERBANK GIRO
# 10                         PAY METHOD  =INTERBANK GIRO
# 11                         PAY METHOD  =INTERBANK GIRO
# 12   B/O CUSTOMER=BTS TANKERS PTE LIMITEDMAYBANK TO...
# 13                         PAY METHOD  =INTERBANK GIRO
# 14                         PAY METHOD  =INTERBANK GIRO
# 15                         PAY METHOD  =INTERBANK GIRO
# 16                         PAY METHOD  =INTERBANK GIRO
# 17   B/O CUSTOMER=BTS TANKERS PTE LIMITEDMAYBANK TO...
# 18                         PAY METHOD  =INTERBANK GIRO
# 19                         PAY METHOD  =INTERBANK GIRO
# 20                         PAY METHOD  =INTERBANK GIRO
# 21                         PAY METHOD  =INTERBANK GIRO
# 22   B/O CUSTOMER=BTS TANKERS PTE LIMITEDMAYBANK TO...
# 23                         PAY METHOD  =INTERBANK GIRO
# 24                         PAY METHOD  =INTERBANK GIRO
# 25                         PAY METHOD  =INTERBANK GIRO
# 26                         PAY METHOD  =INTERBANK GIRO
# 27   B/O CUSTOMER=BTS TANKERS PTE LIMITEDMAYBANK TO...
# 28                         PAY METHOD  =INTERBANK GIRO
# 29                         PAY METHOD  =INTERBANK GIRO
# ..                                                 ...
# 496  B/O CUSTOMER=1/EVONIK METHIONINESEA PTE LTD.3 ...
# 497  B/O CUSTOMER=ENERGETIC MARKETING PTE. LTD.111 ...
# 498  B/O CUSTOMER=ENEOS ITALSING PTE. LTD.9B JURONG...
# 499  B/O CUSTOMER=ENEOS ITALSING PTE. LTD.9B JURONG...
# 500             BENEFICIARY =CHEVRON SINGAPORE PTE LTD
# 501                      CHASE REF   =7299SIH002330000
# 502                      CHASE REF   =7297SIH004160000
# 503                      CHASE REF   =7325SIH004690000
# 504                             EXCH RATE   =1.0000000
# 505                             EXCH RATE   =1.0000000
# 506  B/O CUSTOMER=CHEVRON HONG KONG LTDUNIT 1501 15...
# 507  B/O CUSTOMER=CHEVRON HONG KONG LTDUNIT 1501 15...
# 508  B/O CUSTOMER=CHEVRON HONG KONG LTDUNIT 1501 15...
# 509  B/O CUSTOMER=CHEVRON HONG KONG LTDUNIT 1501 15...
# 510  B/O CUSTOMER=CHEVRON HONG KONG LTDUNIT 1501 15...
# 511  B/O CUSTOMER=CHEVRON HONG KONG LTDUNIT 1501 15...
# 512  B/O CUSTOMER=CHEVRON THAILAND NGD HOLDING, LTD...
# 513  B/O CUSTOMER=/811165554 CALTEX AUSTRALIA LIMIT...
# 514  B/O CUSTOMER=/40550445 BP INTERNATIONAL LTD. B...
# 515  B/O CUSTOMER=/0850913013 BILSEA INTERNATIONAL ...
# 516  B/O CUSTOMER=/0850913013 BILSEA INTERNATIONAL ...
# 517                        PAY METHOD  =INTERBANK GIRO
# 518  B/O CUSTOMER=/64010085750 ARC ENERGY TRADING P...
# 519  B/O CUSTOMER=/469800283 AMPOL SINGAPORE TRADIN...
# 520  B/O CUSTOMER=/469800283 AMPOL SINGAPORE TRADIN...
# 521  B/O CUSTOMER=AMPOL SINGAPORE TRADING PTE LTD3 ...
# 522  B/O CUSTOMER=AMPOL SINGAPORE TRADING PTE LTD3 ...
# 523  B/O CUSTOMER=AMPOL SINGAPORE TRADING PTE LTD3 ...
# 524  B/O CUSTOMER=AMPOL SINGAPORE TRADING PTE LTD3 ...
# 525  B/O CUSTOMER=AMPOL SINGAPORE TRADING PTE LTD3 ...
#
# [526 rows x 4 columns]
