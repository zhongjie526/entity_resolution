# %%
import pandas as pd

data = pd.read_excel("CCN 0838 Bank Statements_CITI_Oct-Dec 2017.xls",names=['col1','col2','col3','col4','col5','col6','col7'])
data
# Out:
#                                                     col1  \
# 0                       Account Statement Details Report
# 1            Report Date 06/05/2018 18:04:17 (GMT+08:00)
# 2                        = Indicates Calculated Balances
# 3                                              Bank Name
# 4                                 Customer Number / Name
# 5                                   Branch Number / Name
# 6                                  Account Number / Name
# 7                                Account Currency / Type
# 8                                         Statement Date
# 9                                 Opening Ledger Balance
# 10                      Current / Closing Ledger Balance
# 11                             Opening Available Balance
# 12                   Current / Closing Available Balance
# 13                                        Bank Reference
# 14                                    Customer Reference
# ...

# %%
data[data.col1=='Bank Reference'][['col2']].rename(columns={'col2':'Bank Reference'}).reset_index(drop=True).T.to_dict().values()
# Out:
# [{'Bank Reference': u'S067275122BF01'},
#  {'Bank Reference': u'S06727514F1201'},
#  {'Bank Reference': u'S06727514BAA01'},
#  {'Bank Reference': u'C0072751974201'},
#  {'Bank Reference': u'C0072751981801'},
#  {'Bank Reference': u'D0372710177801'},
#  {'Bank Reference': u'31727508369    1'},
#  {'Bank Reference': u'D0372720624901'},
#  {'Bank Reference': u'C0072764501001'},
#  {'Bank Reference': u'C0072764515401'},
#  {'Bank Reference': u'C0072762401901'},
#  {'Bank Reference': u'S06727613ECA01'},
#  {'Bank Reference': u'C0072761998901'},
#  {'Bank Reference': u'C0072762767101'},
#  {'Bank Reference': u'C0072761674901'},
#  {'Bank Reference': u'C0072760314301'},
#  {'Bank Reference': u'S0672760CD1C01'},
#  {'Bank Reference': u'D0372760283301'},
#  {'Bank Reference': u'D0372760283201'},
#  {'Bank Reference': u'D0372760282701'},
#  {'Bank Reference': u'D0372760282201'},
#  {'Bank Reference': u'31727608382    1'},
#  {'Bank Reference': u'21727708395    1'},
# ...
